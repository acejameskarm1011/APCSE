# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

# %%
Data = np.array([[49, 62], [46, 62], [45, 64], [44, 66], [43, 70], [42, 76], [41, 79], [40, 82], [40, 87],
                 [40, 92], [40, 97], [40, 102], [40, 107], [40, 112], [41, 115], [42, 120], [43, 124], [45, 126], [48, 127], [49, 128]])

y = Data[:,0]
x = Data[:,1]

plt.plot(x,y)
